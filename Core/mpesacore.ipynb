# %%
from mpesa import Config
# Out:
# Running cells with 'myenv (Python -1.-1.-1)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/Users/netbeans/Documents/ReportWriter/RepotsUI/myenv/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
# Out:
# Running cells with 'myenv (Python -1.-1.-1)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/Users/netbeans/Documents/ReportWriter/RepotsUI/myenv/bin/python -m pip install ipykernel -U --force-reinstall'
